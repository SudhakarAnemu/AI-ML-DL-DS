# %% [markdown]
# <center><img src="https://github.com/insaid2018/Term-1/blob/master/Images/INSAID_Full%20Logo.png?raw=true" width="240" height="360" /></center>
#
# <center><img src="https://raw.githubusercontent.com/insaid2018/DeepLearning/master/image/keras-logo-2018-large-1200.png" style="width: 600px;"/></center>

# %% [markdown]
# # <center>Keras Assignment</center>

# %% [markdown]
# ## Table of Content
#
#
# 1. [Linear Regression in Keras](#section1)<br>
# 2. [Logistic Regression in Keras](#section2)<br>

# %% [markdown]
# <a id=section1></a>

# %% [markdown]
# ## Linear Regression in Keras

# %% [markdown]
# ### The Boston Housing Price dataset

# %% [markdown]
# - You’ll attempt to predict the median price of homes in a given Boston suburb in the mid-1970s, given data points about the suburb at the time, such as the crime rate, the local property tax rate, and so on.
#
#
# - The dataset has relatively few data points: only 506, split between 404 training samples and 102 test samples.
#
#
# - And each feature in the input data (for example, the crime rate) has a different scale.
#   - For instance, some values are proportions, which take values between 0 and 1;
#   - Others take values between 1 and 12, others between 0 and 100, and so on.

# %% [markdown]
# ### 1. Loading the Boston housing dataset

# %%
# Import tensorflow 2.x
# This code block will only work in Google Colab.
try:
    # %tensorflow_version only exists in Colab.
    # %tensorflow_version 2.x
except Exception:
    pass
# Out:
# TensorFlow 2.x selected.

# %%
import numpy as np

from tensorflow.keras.datasets import boston_housing

# %%
(train_data, train_targets), (test_data, test_targets) = boston_housing.load_data()

# %% [markdown]
# - Let’s look at the data:

# %%
train_data.shape
# Out:
# (404, 13)

# %%
test_data.shape
# Out:
# (102, 13)

# %% [markdown]
# - As you can see, you have 404 training samples and 102 test samples, each with 13 numerical features, such as per capita crime rate, average number of rooms per dwelling, accessibility to highways, and so on.
#
#
# - The targets are the median values of owner-occupied homes, in thousands of dollars:

# %%
train_targets
# Out:
# array([15.2, 42.3, 50. , 21.1, 17.7, 18.5, 11.3, 15.6, 15.6, 14.4, 12.1,
#        17.9, 23.1, 19.9, 15.7,  8.8, 50. , 22.5, 24.1, 27.5, 10.9, 30.8,
#        32.9, 24. , 18.5, 13.3, 22.9, 34.7, 16.6, 17.5, 22.3, 16.1, 14.9,
#        23.1, 34.9, 25. , 13.9, 13.1, 20.4, 20. , 15.2, 24.7, 22.2, 16.7,
#        12.7, 15.6, 18.4, 21. , 30.1, 15.1, 18.7,  9.6, 31.5, 24.8, 19.1,
#        22. , 14.5, 11. , 32. , 29.4, 20.3, 24.4, 14.6, 19.5, 14.1, 14.3,
#        15.6, 10.5,  6.3, 19.3, 19.3, 13.4, 36.4, 17.8, 13.5, 16.5,  8.3,
#        14.3, 16. , 13.4, 28.6, 43.5, 20.2, 22. , 23. , 20.7, 12.5, 48.5,
#        14.6, 13.4, 23.7, 50. , 21.7, 39.8, 38.7, 22.2, 34.9, 22.5, 31.1,
#        28.7, 46. , 41.7, 21. , 26.6, 15. , 24.4, 13.3, 21.2, 11.7, 21.7,
#        19.4, 50. , 22.8, 19.7, 24.7, 36.2, 14.2, 18.9, 18.3, 20.6, 24.6,
#        18.2,  8.7, 44. , 10.4, 13.2, 21.2, 37. , 30.7, 22.9, 20. , 19.3,
#        31.7, 32. , 23.1, 18.8, 10.9, 50. , 19.6,  5. , 14.4, 19.8, 13.8,
#        19.6, 23.9, 24.5, 25. , 19.9, 17.2, 24.6, 13.5, 26.6, 21.4, 11.9,
#        22.6, 19.6,  8.5, 23.7, 23.1, 22.4, 20.5, 23.6, 18.4, 35.2, 23.1,
#        27.9, 20.6, 23.7, 28. , 13.6, 27.1, 23.6, 20.6, 18.2, 21.7, 17.1,
#         8.4, 25.3, 13.8, 22.2, 18.4, 20.7, 31.6, 30.5, 20.3,  8.8, 19.2,
#        19.4, 23.1, 23. , 14.8, 48.8, 22.6, 33.4, 21.1, 13.6, 32.2, 13.1,
#        23.4, 18.9, 23.9, 11.8, 23.3, 22.8, 19.6, 16.7, 13.4, 22.2, 20.4,
#        21.8, 26.4, 14.9, 24.1, 23.8, 12.3, 29.1, 21. , 19.5, 23.3, 23.8,
#        17.8, 11.5, 21.7, 19.9, 25. , 33.4, 28.5, 21.4, 24.3, 27.5, 33.1,
#        16.2, 23.3, 48.3, 22.9, 22.8, 13.1, 12.7, 22.6, 15. , 15.3, 10.5,
#        24. , 18.5, 21.7, 19.5, 33.2, 23.2,  5. , 19.1, 12.7, 22.3, 10.2,
#        13.9, 16.3, 17. , 20.1, 29.9, 17.2, 37.3, 45.4, 17.8, 23.2, 29. ,
#        22. , 18. , 17.4, 34.6, 20.1, 25. , 15.6, 24.8, 28.2, 21.2, 21.4,
#        23.8, 31. , 26.2, 17.4, 37.9, 17.5, 20. ,  8.3, 23.9,  8.4, 13.8,
#         7.2, 11.7, 17.1, 21.6, 50. , 16.1, 20.4, 20.6, 21.4, 20.6, 36.5,
#         8.5, 24.8, 10.8, 21.9, 17.3, 18.9, 36.2, 14.9, 18.2, 33.3, 21.8,
#        19.7, 31.6, 24.8, 19.4, 22.8,  7.5, 44.8, 16.8, 18.7, 50. , 50. ,
#        19.5, 20.1, 50. , 17.2, 20.8, 19.3, 41.3, 20.4, 20.5, 13.8, 16.5,
#        23.9, 20.6, 31.5, 23.3, 16.8, 14. , 33.8, 36.1, 12.8, 18.3, 18.7,
#        19.1, 29. , 30.1, 50. , 50. , 22. , 11.9, 37.6, 50. , 22.7, 20.8,
#        23.5, 27.9, 50. , 19.3, 23.9, 22.6, 15.2, 21.7, 19.2, 43.8, 20.3,
#        33.2, 19.9, 22.5, 32.7, 22. , 17.1, 19. , 15. , 16.1, 25.1, 23.7,
#        28.7, 37.2, 22.6, 16.4, 25. , 29.8, 22.1, 17.4, 18.1, 30.3, 17.5,
#        24.7, 12.6, 26.5, 28.7, 13.3, 10.4, 24.4, 23. , 20. , 17.8,  7. ,
#        11.8, 24.4, 13.8, 19.4, 25.2, 19.4, 19.4, 29.1])

# %% [markdown]
# ### 2. Preparing the Data

# %% [markdown]
# - Normalizing the data.

# %%
mean = train_data.mean(axis=0)

# %%
train_data -= mean

# %%
std = train_data.std(axis=0)

# %%
train_data /= std

# %%
test_data -= mean

# %%
test_data /= std

# %% [markdown]
# ### 3. Build the Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# #### Question 1: Instantiate a Sequential model.

# %%
def init_model():
    model = Sequential()

    return model

# %%
model = init_model()

# %% [markdown]
# #### Question 2: Add layers to the model.
#
# - Add 3 Dense layers to the model.
#
#
# - 1st layer should contain:
#   - **64** hidden units
#   - **relu** activation function
#   - input shape in the form of a tuple **(num_of_columns_in_train_set,)**
#
#
# - 2nd layer should contain:
#   - **64** hidden units
#   - **relu** activation function
#
#
# - 3rd layer should contain:
#   - Hidden units equal to the number of outputs we get at the end of a regression problem i.e. **1**.
#   - Use **linear** activation function or don't use activation function at all (this will use the default activation function which is linear).

# %%
def build_model(model):
    model.add(Dense(64, activation='relu', input_shape=(train_data.shape[1],)))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1))

    return model

# %%
model = build_model(model)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 64)                896
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 5,121
# Trainable params: 5,121
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Question 3: Compile the model.
#
# - Use **adam** `optimizer`, and **mse** as `loss`.
#
# - Use **mae** in the `metrics` parameter.

# %%
def compile_model(model):
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])

    return model

# %%
model = compile_model(model)

# %% [markdown]
# #### Question 4: Train the Model
#
# - Fit the model with the training data.
#
# - Use **80 number of epochs**, and **batch size of 16** in the `fit` function.
#
# - Don't specify any other hyperparameter.

# %%
def fit_model(model):
    model.fit(train_data, train_targets, epochs=80, batch_size=16)

    return model

# %%
model = fit_model(model)
# Out:
# 404/404 [==============================] - 5s 12ms/step - loss: 537.3262 - mean_absolute_error: 21.2841
# Epoch 2/80
# 404/404 [==============================] - 0s 254us/step - loss: 403.6577 - mean_absolute_error: 17.8909
# Epoch 3/80
# 404/404 [==============================] - 0s 249us/step - loss: 6.8553 - mean_absolute_error: 1.8915
# Epoch 59/80
# 404/404 [==============================] - 0s 271us/step - loss: 6.9374 - mean_absolute_error: 1.8829
# Epoch 60/80
# 404/404 [==============================] - 0s 249us/step - loss: 6.7627 - mean_absolute_error: 1.8630
# Epoch 61/80
# 404/404 [==============================] - 0s 268us/step - loss: 6.7466 - mean_absolute_error: 1.8765
# Epoch 62/80
# 404/404 [==============================] - 0s 255us/step - loss: 6.4279 - mean_absolute_error: 1.8247
# Epoch 63/80
# 404/404 [==============================] - 0s 242us/step - loss: 6.8452 - mean_absolute_error: 1.8959
# Epoch 64/80
# 404/404 [==============================] - 0s 257us/step - loss: 6.7192 - mean_absolute_error: 1.8547
# Epoch 65/80
# 404/404 [==============================] - 0s 248us/step - loss: 6.3834 - mean_absolute_error: 1.8463
# Epoch 66/80
# 404/404 [==============================] - 0s 259us/step - loss: 6.2691 - mean_absolute_error: 1.7609
# Epoch 67/80
# 404/404 [==============================] - 0s 238us/step - loss: 6.0991 - mean_absolute_error: 1.7742
# Epoch 68/80
# 404/404 [==============================] - 0s 251us/step - loss: 6.4201 - mean_absolute_error: 1.8468
# Epoch 69/80
# 404/404 [==============================] - 0s 282us/step - loss: 6.1287 - mean_absolute_error: 1.7971
# Epoch 70/80
# 404/404 [==============================] - 0s 291us/step - loss: 6.0088 - mean_absolute_error: 1.7537
# Epoch 71/80
# 404/404 [==============================] - 0s 264us/step - loss: 6.1284 - mean_absolute_error: 1.7497
# Epoch 72/80
# 404/404 [==============================] - 0s 244us/step - loss: 6.1485 - mean_absolute_error: 1.7621
# Epoch 73/80
# 404/404 [==============================] - 0s 232us/step - loss: 5.9328 - mean_absolute_error: 1.7776
# Epoch 74/80
# 404/404 [==============================] - 0s 256us/step - loss: 5.7794 - mean_absolute_error: 1.7111
# Epoch 75/80
# 404/404 [==============================] - 0s 269us/step - loss: 5.7012 - mean_absolute_error: 1.6960
# Epoch 76/80
# 404/404 [==============================] - 0s 254us/step - loss: 5.7241 - mean_absolute_error: 1.7244
# Epoch 77/80
# 404/404 [==============================] - 0s 254us/step - loss: 5.6866 - mean_absolute_error: 1.7205
# Epoch 78/80
# 404/404 [==============================] - 0s 309us/step - loss: 5.6716 - mean_absolute_error: 1.6958
# Epoch 79/80
# 404/404 [==============================] - 0s 237us/step - loss: 5.5261 - mean_absolute_error: 1.7105
# Epoch 80/80
# 404/404 [==============================] - 0s 248us/step - loss: 5.6729 - mean_absolute_error: 1.6851

# %% [markdown]
# #### Question 5: Evaluate the Model on the Test data.
#
# - Use the `evaluate` funtion to evaluate the model on the test data.

# %%
def evaluate_model(model):
    test_mse_score, test_mae_score = model.evaluate(test_data, test_targets)

    return test_mse_score, test_mae_score

# %%
test_mse_score, test_mae_score = evaluate_model(model)
# Out:
# 102/102 [==============================] - 0s 370us/step

# %% [markdown]
# - Here’s the final result on the test dataset:

# %%
print('Mean Absolute Error:', test_mae_score)
print('Mean Squared Error:', test_mse_score)
# Out:
# Mean Absolute Error: 2.6399879549063887
# Mean Squared Error: 17.82345132266774

# %%
print('Root Mean Squared Error:', np.sqrt(test_mse_score))
# Out:
# Root Mean Squared Error: 4.22178295541916

# %% [markdown]
# ## Logistic Regression in Keras

# %% [markdown]
# ### Titanic Dataset

# %% [markdown]
# The goal is to __predict survival__ of passengers travelling in RMS __Titanic__ using __Logistic regression__.

# %% [markdown]
# ### 1. Loading the Titanic Dataset

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Casestudy/titanic_train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# - The dataset consists of the information about people boarding the famous RMS Titanic. Various variables present in the dataset includes data of age, sex, fare, ticket etc.
#
#
# - The dataset comprises of __891 observations of 12 columns__. Below is a table showing names of all the columns and their description.

# %% [markdown]
# | Column Name   | Description                                               |
# | ------------- |:---------------------------------------------------------:|
# | PassengerId   | Passenger Identity                                        |
# | Survived      | Whether passenger survived or not                         |
# | Pclass        | Class of ticket                                           |
# | Name          | Name of passenger                                         |
# | Sex           | Sex of passenger                                          |
# | Age           | Age of passenger                                          |
# | SibSp         | Number of sibling and/or spouse travelling with passenger |
# | Parch         | Number of parent and/or children travelling with passenger|
# | Ticket        | Ticket number                                             |
# | Fare          | Price of ticket                                           |
# | Cabin         | Cabin number                                              |

# %% [markdown]
# ### 2. Preparing the Data

# %% [markdown]
# - Dealing with missing values<br/>
#     - Dropping/Replacing missing entries of __Embarked.__
#     - Replacing missing values of __Age__ and __Fare__ with median values.
#     - Dropping the column __'Cabin'__ as it has too many _null_ values.

# %%
df.Embarked = df.Embarked.fillna(df['Embarked'].mode()[0])

# %%
median_age = df.Age.median()
median_age
# Out:
# 28.0

# %%
median_fare = df.Fare.median()
median_fare
# Out:
# 14.4542

# %%
df.Age.fillna(median_age, inplace = True)
df.Fare.fillna(median_fare, inplace = True)

# %%
df.drop('Cabin', axis = 1,inplace = True)

# %% [markdown]
# - Creating a new feature named __FamilySize__.

# %%
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Embarked  FamilySize
# 0            1         0       3  ...   7.2500        S           2
# 1            2         1       1  ...  71.2833        C           2
# 2            3         1       3  ...   7.9250        S           1
# 3            4         1       1  ...  53.1000        S           2
# 4            5         0       3  ...   8.0500        S           1
#
# [5 rows x 12 columns]

# %% [markdown]
# - Segmenting __Sex__ column as per __Age__, Age less than 15 as __Child__, Age greater than 15 as __Males and Females__ as per their gender.

# %%
df['GenderClass'] = df.apply(lambda x: 'child' if x['Age'] < 15 else x['Sex'], axis=1)

# %%
df[df.Age < 15].head(2)
# Out:
#    PassengerId  Survived  Pclass  ... Embarked FamilySize  GenderClass
# 7            8         0       3  ...        S          5        child
# 9           10         1       2  ...        C          2        child
#
# [2 rows x 13 columns]

# %%
df[df.Age > 15].head(2)
# Out:
#    PassengerId  Survived  Pclass  ... Embarked FamilySize  GenderClass
# 0            1         0       3  ...        S          2         male
# 1            2         1       1  ...        C          2       female
#
# [2 rows x 13 columns]

# %% [markdown]
# - __Dummification__ of __GenderClass__ & __Embarked__.

# %%
df = pd.get_dummies(df, columns=['GenderClass', 'Embarked'], drop_first=True)

# %% [markdown]
# - __Dropping__ columns __'Name' , 'Ticket' , 'Sex' , 'SibSp' and 'Parch'__

# %%
df.drop(['Name','Ticket','Sex','SibSp','Parch'], axis = 1, inplace=True)
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...  GenderClass_male  Embarked_Q  Embarked_S
# 0            1         0       3  ...                 1           0           1
# 1            2         1       1  ...                 0           0           0
# 2            3         1       3  ...                 0           0           1
# 3            4         1       1  ...                 0           0           1
# 4            5         0       3  ...                 1           0           1
#
# [5 rows x 10 columns]

# %% [markdown]
# - Preparing X and y using pandas.

# %%
X = df.loc[:, df.columns != 'Survived']
X.head()
# Out:
#    PassengerId  Pclass   Age  ...  GenderClass_male  Embarked_Q  Embarked_S
# 0            1       3  22.0  ...                 1           0           1
# 1            2       1  38.0  ...                 0           0           0
# 2            3       3  26.0  ...                 0           0           1
# 3            4       1  35.0  ...                 0           0           1
# 4            5       3  35.0  ...                 1           0           1
#
# [5 rows x 9 columns]

# %%
y = df.Survived
y[:10]
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# 5    0
# 6    0
# 7    0
# 8    1
# 9    1
# Name: Survived, dtype: int64

# %% [markdown]
# - Splitting the dataset into train and test sets.

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (712, 9)
# (712,)
# (179, 9)
# (179,)

# %% [markdown]
# ### 3. Build the Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# #### Question 6: Instantiate a Sequential model.

# %%
def init_model():
    model = Sequential()

    return model

# %%
model = init_model()

# %% [markdown]
# #### Question 7: Add layers to the model.
#
# - Add 3 Dense layers to the model.
#
#
# - 1st layer should contain:
#   - **64** hidden units
#   - **relu** activation function
#   - input shape in the form of a tuple **(num_of_columns_in_train_set,)**
#
#
# - 2nd layer should contain:
#   - **64** hidden units
#   - **relu** activation function
#
#
# - 3rd layer should contain:
#   - Hidden units equal to the number of outputs we get at the end of a binary classification problem i.e. **1**.
#   - Use **sigmoid** activation function (**sigmoid** activation function is used in **binary** classification problems in the last layer).

# %%
def build_model(model):
    model.add(Dense(64, activation='relu', input_shape=(X_train.shape[1],)))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    return model

# %%
model = build_model(model)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 64)                640
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 4,865
# Trainable params: 4,865
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Question 8: Compile the model.
#
# - Use **adam** `optimizer`, and **binary_crossentropy** as `loss`.
#
# - Use **accuracy** in the `metrics` parameter.

# %%
def compile_model(model):
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

    return model

# %%
model = compile_model(model)

# %% [markdown]
# #### Question 9: Train the Model
#
# - Fit the model with the training data.
#
# - Use **100 number of epochs**, and **batch size of 16** in the `fit` function.
#
# - Don't specify any other hyperparameter.

# %%
def fit_model(model):
    history = model.fit(X_train, y_train, epochs=100, batch_size=16)

    return model, history

# %%
model, history = fit_model(model)
# Out:
# Epoch 1/100
# 712/712 [==============================] - 1s 765us/step - loss: 1.2492 - acc: 0.6180
# Epoch 2/100
# 712/712 [==============================] - 0s 283us/step - loss: 0.8302 - acc: 0.6222
# Epoch 3/100
# 712/712 [==============================] - 0s 286us/step - loss: 0.8228 - acc: 0.6601
# Epoch 4/100
# 712/712 [==============================] - 0s 291us/step - loss: 0.7275 - acc: 0.6742
# Epoch 5/100
# 712/712 [==============================] - 0s 283us/step - loss: 0.7161 - acc: 0.6699
# Epoch 6/100
# 712/712 [==============================] - 0s 289us/step - loss: 0.7372 - acc: 0.6531
# Epoch 7/100
# 712/712 [==============================] - 0s 302us/step - loss: 0.7119 - acc: 0.7205
# Epoch 8/100
# 712/712 [==============================] - 0s 329us/step - loss: 0.5843 - acc: 0.7135
# Epoch 9/100
# 712/712 [==============================] - 0s 301us/step - loss: 0.5761 - acc: 0.7289
# Epoch 10/100
# 712/712 [==============================] - 0s 277us/step - loss: 0.5258 - acc: 0.7584
# Epoch 11/100
# 712/712 [==============================] - 0s 322us/step - loss: 0.5274 - acc: 0.7528
