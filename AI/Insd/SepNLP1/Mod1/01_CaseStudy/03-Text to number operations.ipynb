# %% [markdown]
# <center><img src="https://github.com/insaid2018/Term-1/blob/master/Images/INSAID_Full%20Logo.png?raw=true" width="360" height="160" /></center>

# %% [markdown]
# <center><img src = "https://raw.githubusercontent.com/insaid2018/Term-1/master/Images/vec23.JPG"/></center>

# %% [markdown]
# ## Vectors
#  - A vector is an **object** that has both a **magnitude** and a **direction**.
#  - The **direction** of the vector is from its **tail** to its **head**.
#
#  <center><img src = "https://raw.githubusercontent.com/insaid2018/Term-1/master/Images/vector.png" height = "150"/></center>

# %% [markdown]
# - Vectors are **added** by connecting them **head to tail**.
#
#  <center><img src =" https://raw.githubusercontent.com/insaid2018/Term-1/master/Images/vector%20addition.JPG"/></center>
#
# - Vectors are **subtracted** by **reversing heads and tails** for the subtracted vector, and then connecting them **head to tail.**
#
# <center><img src = "https://raw.githubusercontent.com/insaid2018/Term-1/master/Images/vector%20subtraction.JPG"/></center>

# %% [markdown]
# ## Lets perform basic mathematical operations on the generated embeddings.
# - **For Example** : King - Man + Woman = vector close to Queen.

# %% [markdown]
# <center><img src= "https://raw.githubusercontent.com/insaid2018/Term-1/master/Images/s_7F7F52CDA5C440D8FA8A15AEE4B7E5C0026FCD9A44A7D7FBC332306EAEDC151F_1545166550863_king-queen-man-woman.png"/></center>

# %% [markdown]
# ### Subtracting Man from Woman

# %% [markdown]
# <center><img src ="https://raw.githubusercontent.com/insaid2018/Term-1/master/Images/k2.png"/></center>

# %% [markdown]
# ### Adding it to king

# %% [markdown]
# <center><img src= "https://raw.githubusercontent.com/insaid2018/Term-1/master/Images/k3.png"/></center>

# %% [markdown]
# ### And the closest word embedding is Queen

# %% [markdown]
# <center><img src = "https://raw.githubusercontent.com/insaid2018/Term-1/master/Images/k4.png"/></center>

# %% [markdown]
# <center><img src = "https://raw.githubusercontent.com/insaid2018/Term-1/master/Images/queen2.jpg" width = "200" height = "100"/></center>

# %% [markdown]
# ## Lets understand this through a simple code.

# %%
import warnings
import nltk
nltk.download('brown')
warnings.filterwarnings(action = 'ignore')
# Out:
# [nltk_data] Downloading package brown to /home/nbuser/nltk_data...
# [nltk_data]   Package brown is already up-to-date!

# %%
# !pip install gensim

# %%
from nltk.corpus import brown
from gensim.models import Word2Vec

# %% [markdown]
# ## We take only words that appear more than 150 times for doing a visualization later

# %%
from gensim.models.word2vec import Text8Corpus
w2v_model2 = Word2Vec(Text8Corpus('text8'), size=100, window=5, min_count=150, workers=4)

# %% [markdown]
# ## Getting most similar vectors

# %%
print(w2v_model2.wv.most_similar('king'))
# Out:
# [('prince', 0.7811065912246704), ('duke', 0.729900598526001), ('emperor', 0.7279906868934631), ('vii', 0.7272508144378662), ('castile', 0.7253075838088989), ('regent', 0.7198089957237244), ('constantine', 0.7157908082008362), ('sultan', 0.7097324132919312), ('throne', 0.6969749927520752), ('viii', 0.6794503927230835)]

# %% [markdown]
# ##  "King" - "Man" + "Woman" == "Queen"

# %%
print(w2v_model2.most_similar(positive=['woman', 'king'], negative=['man'], topn=3))
# Out:
# [('prince', 0.6553115248680115), ('emperor', 0.6460045576095581), ('queen', 0.6390155553817749)]

# %% [markdown]
# <center><img src = "https://raw.githubusercontent.com/insaid2018/Term-1/master/Images/kingqueen.JPG"/></center>
